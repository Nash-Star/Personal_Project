# %% [markdown]
# ## Skenario 2
# ### Dengan Conv 32, hidden layer 128, lr 0.01

# %%
# akses Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
##### CNN MODEL ####
# %tensorflow_version 1.x 
import warnings
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras import initializers
from keras.preprocessing.image import ImageDataGenerator


warnings.filterwarnings("ignore")
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializers.he_uniform(seed=1), padding='same', input_shape=(200, 200, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer=initializers.he_uniform(seed=1)))
	model.add(Dense(3, activation='softmax'))
	# compile model
	opt = SGD(lr=0.01, momentum=0.9)
	#opt = Adam(lr=0.001, beta_1=0.9, beta_2=0.099, amsgrad=False)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	# %matplotlib inline
	pyplot.figure(figsize=(8, 8), dpi=300)
	# plot loss
	pyplot.subplot(211)
	pyplot.title('Model Cross Entropy Loss')
	pyplot.xlabel('Number of Epochs')
	pyplot.ylabel('Cross Entropy Loss')
	pyplot.ylim(0,2)
	pyplot.plot(history.history['loss'], color='blue', label='train')
	pyplot.plot(history.history['val_loss'], color='orange', label='test')
	pyplot.legend()
	print("\n")
	# plot accuracy
	pyplot.subplot(212)
	pyplot.title('Model Classification Accuracy')
	pyplot.xlabel('Number of Epochs')
	pyplot.ylabel('Classification Accuracy')
	pyplot.plot(history.history['accuracy'], color='blue', label='train')
	pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
	pyplot.legend()
	pyplot.tight_layout(pad=2.0)
	pyplot.show()
	#print(history.history.keys())
  #dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
  # save plot to file
	#filename = sys.argv[0].split('/')[-1]
	#pyplot.savefig(filename + '_plot.png')
	#pyplot.close()

# %%
### COBA Confusion Matrix (bisa)

# run the test harness for evaluating a model
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns
def run_test_harness():
  # define model
  model = define_model()
  # create data generator
  datagen = ImageDataGenerator(rescale=1.0/255.0)
  #datagen = ImageDataGenerator()
  # prepare iterators
  train_it = datagen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/Dataset/RIPCurrent_keras/train/',
  	class_mode='categorical', batch_size=8, target_size=(200, 200))
  test_it = datagen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/Dataset/RIPCurrent_keras/test/',
  	class_mode='categorical', batch_size=8, target_size=(200, 200))
  # fit model
  history = model.fit_generator(train_it, steps_per_epoch=len(train_it)/8,
  	validation_data=test_it, validation_steps=len(test_it)/8, epochs=50, verbose=2)
  # Save history training data
  loss = pd.DataFrame(history.history) 
  hist_csv_file = 'history.csv'
  with open(hist_csv_file, mode='w') as f:
    loss.to_csv(f)
  # evaluate model
  # predict test data
  test_it.reset()
  Y_pred = model.predict_generator(test_it)
  classes = test_it.classes[test_it.index_array]
  y_pred = np.argmax(Y_pred, axis=-1)
  # using confusion matrix
  cm = confusion_matrix(test_it.classes[test_it.index_array],y_pred)
  confusmatrix = pd.DataFrame(cm)
  confusmatrix.columns = ['Rip 1','Rip 2','No Rip']
  confusmatrix.rename(index={0:'Rip 1', 1:'Rip 2', 2:'No Rip'}, inplace=True)  
  plot_cm = sns.heatmap(confusmatrix, annot=True, fmt="d")
  pyplot.xlabel("Predicted Label")
  pyplot.ylabel("True Label")
  pyplot.show()
  # calculate Accuracy
  _, acc = model.evaluate_generator(test_it, steps=2, verbose=0)
  print('Akurasi Model: %.5f' % (acc * 100.0))
  # learning curves
  summarize_diagnostics(history)
  # save model
  model.save('rip_model.h5')

# %%
# entry point, run the test harness
from datetime import datetime

toc = datetime.now()
run_test_harness()
tic = datetime.now()

print("Waktu running Model = {}".format(tic-toc))
# Out:
# Found 444 images belonging to 3 classes.
# Found 141 images belonging to 3 classes.
# Epoch 1/50
#  - 7s - loss: 16.3376 - accuracy: 0.4464 - val_loss: 1.1867 - val_accuracy: 0.4167
# Epoch 2/50
#  - 6s - loss: 1.0781 - accuracy: 0.5357 - val_loss: 0.7633 - val_accuracy: 0.7083
# Epoch 3/50
#  - 5s - loss: 1.0188 - accuracy: 0.5179 - val_loss: 0.4813 - val_accuracy: 0.6250
# Epoch 4/50
#  - 5s - loss: 1.0288 - accuracy: 0.5000 - val_loss: 0.6662 - val_accuracy: 0.8333
# Epoch 5/50
#  - 4s - loss: 0.5707 - accuracy: 0.8393 - val_loss: 0.4158 - val_accuracy: 0.8333
# Epoch 6/50
#  - 4s - loss: 1.0987 - accuracy: 0.6250 - val_loss: 1.1848 - val_accuracy: 0.3810
# Epoch 7/50
#  - 6s - loss: 0.9160 - accuracy: 0.5536 - val_loss: 0.9108 - val_accuracy: 0.8333
# Epoch 8/50
#  - 6s - loss: 0.7037 - accuracy: 0.8750 - val_loss: 0.6941 - val_accuracy: 0.7083
# Epoch 9/50
#  - 6s - loss: 1.4338 - accuracy: 0.5000 - val_loss: 1.6843 - val_accuracy: 0.4583
# Epoch 10/50
#  - 4s - loss: 0.7679 - accuracy: 0.6607 - val_loss: 0.7455 - val_accuracy: 0.5833
# Epoch 11/50
#  - 4s - loss: 0.6571 - accuracy: 0.6964 - val_loss: 0.3746 - val_accuracy: 0.9167
# Epoch 12/50
#  - 5s - loss: 1.0410 - accuracy: 0.6346 - val_loss: 0.9075 - val_accuracy: 0.3333
# Epoch 13/50
#  - 6s - loss: 0.8186 - accuracy: 0.6250 - val_loss: 0.6510 - val_accuracy: 0.7500
# Epoch 14/50
#  - 6s - loss: 0.3108 - accuracy: 0.8929 - val_loss: 0.2482 - val_accuracy: 0.8333
# Epoch 15/50
#  - 6s - loss: 0.1495 - accuracy: 0.9464 - val_loss: 0.1225 - val_accuracy: 1.0000
# Epoch 16/50
#  - 4s - loss: 0.2647 - accuracy: 0.8929 - val_loss: 0.3165 - val_accuracy: 0.7083
# Epoch 17/50
#  - 5s - loss: 0.4628 - accuracy: 0.7500 - val_loss: 0.3179 - val_accuracy: 0.7917
# Epoch 18/50
#  - 4s - loss: 0.5215 - accuracy: 0.8214 - val_loss: 0.3781 - val_accuracy: 0.7143
# Epoch 19/50
#  - 6s - loss: 0.9615 - accuracy: 0.6250 - val_loss: 0.8062 - val_accuracy: 0.3333
# Epoch 20/50
#  - 6s - loss: 0.7712 - accuracy: 0.6607 - val_loss: 0.5914 - val_accuracy: 0.7083
# Epoch 21/50
#  - 5s - loss: 0.5961 - accuracy: 0.7679 - val_loss: 0.6740 - val_accuracy: 0.7500
# Epoch 22/50
#  - 5s - loss: 0.3772 - accuracy: 0.9286 - val_loss: 0.3463 - val_accuracy: 0.9167
# Epoch 23/50
#  - 5s - loss: 0.2653 - accuracy: 0.8929 - val_loss: 0.0228 - val_accuracy: 0.8333
# Epoch 24/50
#  - 4s - loss: 0.3101 - accuracy: 0.8846 - val_loss: 0.9564 - val_accuracy: 0.8095
# Epoch 25/50
#  - 6s - loss: 0.2565 - accuracy: 0.8929 - val_loss: 0.2454 - val_accuracy: 0.8750
# Epoch 26/50
#  - 6s - loss: 0.3086 - accuracy: 0.8750 - val_loss: 1.3393 - val_accuracy: 0.5417
# Epoch 27/50
#  - 6s - loss: 0.2223 - accuracy: 0.9286 - val_loss: 0.1231 - val_accuracy: 0.9167
# Epoch 28/50
#  - 5s - loss: 0.1264 - accuracy: 0.9464 - val_loss: 0.4168 - val_accuracy: 0.8333
# Epoch 29/50
#  - 5s - loss: 0.1234 - accuracy: 0.9615 - val_loss: 0.4798 - val_accuracy: 0.7917
# Epoch 30/50
#  - 4s - loss: 0.1163 - accuracy: 0.9464 - val_loss: 0.3400 - val_accuracy: 0.9524
# Epoch 31/50
#  - 6s - loss: 0.1452 - accuracy: 0.9464 - val_loss: 0.0643 - val_accuracy: 0.9167
# Epoch 32/50
#  - 5s - loss: 0.1208 - accuracy: 0.9643 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 33/50
#  - 6s - loss: 0.0556 - accuracy: 0.9821 - val_loss: 0.1820 - val_accuracy: 0.9167
# Epoch 34/50
#  - 5s - loss: 0.0362 - accuracy: 0.9821 - val_loss: 0.0833 - val_accuracy: 0.9583
# Epoch 35/50
#  - 5s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 36/50
#  - 4s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2799 - val_accuracy: 0.8571
# Epoch 37/50
#  - 6s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9583
# Epoch 38/50
#  - 6s - loss: 0.0288 - accuracy: 0.9821 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 39/50
#  - 5s - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 40/50
#  - 6s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9583
# Epoch 41/50
#  - 5s - loss: 8.1350e-04 - accuracy: 1.0000 - val_loss: 2.9878e-04 - val_accuracy: 0.9583
# Epoch 42/50
#  - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 43/50
#  - 6s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.1605e-04 - val_accuracy: 1.0000
# Epoch 44/50
#  - 6s - loss: 6.3708e-05 - accuracy: 1.0000 - val_loss: 2.1283e-04 - val_accuracy: 1.0000
# Epoch 45/50
#  - 5s - loss: 3.0934e-04 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 46/50
#  - 4s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 47/50
#  - 4s - loss: 4.4536e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9583
# Epoch 48/50
#  - 4s - loss: 4.6968e-04 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 49/50
#  - 7s - loss: 2.5512e-04 - accuracy: 1.0000 - val_loss: 3.5691e-04 - val_accuracy: 1.0000
# Epoch 50/50
#  - 6s - loss: 6.3374e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Akurasi Model: 100.00000
# Waktu running Model = 0:04:33.722183

# %%
### tebak gambar
# open image
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import os
 
# load and prepare the image
def load_image(folder):
  images = []
  filenames = []
  for filename in os.listdir(folder):
    img = load_img(os.path.join(folder,filename), target_size=(200, 200))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 3 channels
    img = img.reshape(1, 200, 200, 3)
    img = img.astype('uint8')
    images.append(img)
    filenames.append(filename.replace(".jpg", " "))
  return images, filenames

# %%
coba,nama = load_image('/content/gdrive/My Drive/Colab Notebooks/Dataset/RIPCurrent_keras/coba/')

# %%
(coba[2].shape)
#len(coba)
#type(coba[1])
#print(coba[1])
#print(nama[1])
# Out:
# (1, 200, 200, 3)

# %%
# load an image and predict the class
def run_example(img,name):
  import matplotlib.pyplot as plt
  import pandas as pd
  import numpy as np

  # load model
  model = load_model('rip_model.h5')
  #print(model.summary())
  # predict the class
  result = model.predict(img)
  plt.figure()
  img = img.reshape(200, 200, 3)
  #img = imread(img)
  imgplot = plt.imshow(img)
  plt.title('Nama File asli : {}'.format(name))
  a = np.asarray(result)
  hasil_klasifikasi = pd.DataFrame(a)
  hasil_klasifikasi.columns = ['norip', 'rip 1', 'rip 2'] 
  print ('   Hasil prediksi model : ')
  print(hasil_klasifikasi)

# %%
run_example(coba[14],nama[14])
# Out:
#    Hasil prediksi model :
#    norip  rip 1  rip 2
# 0    0.0    0.0    1.0

# %%
model = load_model('rip_model.h5')
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 200, 200, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 32)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 320000)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               40960128
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 40,961,411
# Trainable params: 40,961,411
# Non-trainable params: 0
# _________________________________________________________________
# None
