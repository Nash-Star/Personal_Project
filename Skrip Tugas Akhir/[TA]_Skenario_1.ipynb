# %% [markdown]
# ## Skenario 1
# ### Dengan Conv 8, hidden layer 32, lr 0.001

# %%
# akses Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
##### CNN MODEL ####
# %tensorflow_version 1.x 
import warnings
import sys
import pandas as pd
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras import initializers
from keras.preprocessing.image import ImageDataGenerator


warnings.filterwarnings("ignore")
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(8, (3, 3), activation='relu', kernel_initializer=initializers.he_uniform(seed=1), padding='same', input_shape=(200, 200, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(16, activation='relu', kernel_initializer=initializers.he_uniform(seed=1)))
	model.add(Dense(3, activation='softmax'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	#opt = Adam(lr=0.001, beta_1=0.9, beta_2=0.099, amsgrad=False)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	# %matplotlib inline
	pyplot.figure(figsize=(8, 8), dpi=300)
	# plot loss
	pyplot.subplot(211)
	pyplot.title('Model Cross Entropy Loss')
	pyplot.xlabel('Number of Epochs')
	pyplot.ylabel('Cross Entropy Loss')
	pyplot.ylim(0,2)
	pyplot.plot(history.history['loss'], color='blue', label='train')
	pyplot.plot(history.history['val_loss'], color='orange', label='test')
	pyplot.legend()
	print("\n")
	# plot accuracy
	pyplot.subplot(212)
	pyplot.title('Model Classification Accuracy')
	pyplot.xlabel('Number of Epochs')
	pyplot.ylabel('Classification Accuracy')
	pyplot.plot(history.history['accuracy'], color='blue', label='train')
	pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
	pyplot.legend()
	pyplot.tight_layout(pad=2.0)
	pyplot.show()
	#print(history.history.keys())
  #dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
  # save plot to file
	#filename = sys.argv[0].split('/')[-1]
	#pyplot.savefig(filename + '_plot.png')
	#pyplot.close()

# %%
### COBA Confusion Matrix (bisa)

# run the test harness for evaluating a model
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns
def run_test_harness():
  # define model
  model = define_model()
  # create data generator
  datagen = ImageDataGenerator(rescale=1.0/255.0)
  #datagen = ImageDataGenerator()
  # prepare iterators
  train_it = datagen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/Dataset/RIPCurrent_keras/train/',
  	class_mode='categorical', batch_size=8, target_size=(200, 200))
  test_it = datagen.flow_from_directory('/content/gdrive/My Drive/Colab Notebooks/Dataset/RIPCurrent_keras/test/',
  	class_mode='categorical', batch_size=8, target_size=(200, 200))
  # fit model
  history = model.fit_generator(train_it, steps_per_epoch=len(train_it)/8,
  	validation_data=test_it, validation_steps=len(test_it)/8, epochs=50, verbose=2)
  # Save history training data
  loss = pd.DataFrame(history.history) 
  hist_csv_file = 'history.csv'
  with open(hist_csv_file, mode='w') as f:
    loss.to_csv(f)
  # evaluate model
  # predict test data
  #test_it.reset()
  Y_pred = model.predict_generator(test_it)
  classes = test_it.classes[test_it.index_array]
  y_pred = np.argmax(Y_pred, axis=-1)
  # using confusion matrix
  cm = confusion_matrix(test_it.classes[test_it.index_array],y_pred)
  confusmatrix = pd.DataFrame(cm)
  confusmatrix.columns = ['Rip 1','Rip 2','No Rip']
  confusmatrix.rename(index={0:'Rip 1', 1:'Rip 2', 2:'No Rip'}, inplace=True)  
  plot_cm = sns.heatmap(confusmatrix, annot=True, fmt="d")
  pyplot.xlabel("Predicted Label")
  pyplot.ylabel("True Label")
  pyplot.show()
  # calculate Accuracy
  _, acc = model.evaluate_generator(test_it, steps=2, verbose=0)
  print('Akurasi Model: %.5f' % (acc * 100.0))
  # learning curves
  summarize_diagnostics(history)
  # save model
  model.save('rip_model.h5')

# %%
# entry point, run the test harness
from datetime import datetime

toc = datetime.now()
run_test_harness()
tic = datetime.now()

print("Waktu running Model = {}".format(tic-toc))
# Out:
# Found 444 images belonging to 3 classes.
# Found 141 images belonging to 3 classes.
# Epoch 1/50
#  - 4s - loss: 1.1027 - accuracy: 0.4231 - val_loss: 1.0958 - val_accuracy: 0.3333
# Epoch 2/50
#  - 4s - loss: 1.0464 - accuracy: 0.4821 - val_loss: 0.9341 - val_accuracy: 0.6250
# Epoch 3/50
#  - 4s - loss: 1.0082 - accuracy: 0.4464 - val_loss: 0.8265 - val_accuracy: 0.8750
# Epoch 4/50
#  - 3s - loss: 0.8052 - accuracy: 0.6964 - val_loss: 0.5762 - val_accuracy: 0.8750
# Epoch 5/50
#  - 3s - loss: 0.5914 - accuracy: 0.8036 - val_loss: 0.5048 - val_accuracy: 0.6667
# Epoch 6/50
#  - 3s - loss: 0.5798 - accuracy: 0.7321 - val_loss: 0.3549 - val_accuracy: 0.6190
# Epoch 7/50
#  - 4s - loss: 0.4564 - accuracy: 0.7857 - val_loss: 0.4233 - val_accuracy: 0.9583
# Epoch 8/50
#  - 4s - loss: 0.4965 - accuracy: 0.8214 - val_loss: 0.3410 - val_accuracy: 0.6667
# Epoch 9/50
#  - 4s - loss: 0.3484 - accuracy: 0.9286 - val_loss: 0.4527 - val_accuracy: 1.0000
# Epoch 10/50
#  - 3s - loss: 0.3327 - accuracy: 0.8929 - val_loss: 0.4024 - val_accuracy: 0.9583
# Epoch 11/50
#  - 3s - loss: 0.2848 - accuracy: 0.9821 - val_loss: 0.2931 - val_accuracy: 1.0000
# Epoch 12/50
#  - 3s - loss: 0.3535 - accuracy: 0.8750 - val_loss: 0.4353 - val_accuracy: 0.9524
# Epoch 13/50
#  - 4s - loss: 0.4318 - accuracy: 0.7500 - val_loss: 0.5013 - val_accuracy: 0.6667
# Epoch 14/50
#  - 4s - loss: 0.2918 - accuracy: 0.8929 - val_loss: 0.2614 - val_accuracy: 0.9167
# Epoch 15/50
#  - 3s - loss: 0.2842 - accuracy: 0.9107 - val_loss: 0.1946 - val_accuracy: 0.9583
# Epoch 16/50
#  - 3s - loss: 0.2561 - accuracy: 0.9107 - val_loss: 0.1477 - val_accuracy: 1.0000
# Epoch 17/50
#  - 3s - loss: 0.1918 - accuracy: 0.9286 - val_loss: 0.2151 - val_accuracy: 1.0000
# Epoch 18/50
#  - 2s - loss: 0.2888 - accuracy: 0.9615 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 19/50
#  - 4s - loss: 0.0870 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 20/50
#  - 4s - loss: 0.1499 - accuracy: 0.9643 - val_loss: 0.1204 - val_accuracy: 1.0000
# Epoch 21/50
#  - 4s - loss: 0.1176 - accuracy: 0.9643 - val_loss: 0.1081 - val_accuracy: 1.0000
# Epoch 22/50
#  - 3s - loss: 0.1081 - accuracy: 0.9643 - val_loss: 0.1269 - val_accuracy: 0.9583
# Epoch 23/50
#  - 3s - loss: 0.0983 - accuracy: 0.9821 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 24/50
#  - 2s - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 25/50
#  - 5s - loss: 0.0833 - accuracy: 0.9643 - val_loss: 0.0554 - val_accuracy: 1.0000
# Epoch 26/50
#  - 4s - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 27/50
#  - 4s - loss: 0.0547 - accuracy: 0.9821 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 28/50
#  - 3s - loss: 0.0636 - accuracy: 0.9821 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 29/50
#  - 2s - loss: 0.0419 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 30/50
#  - 2s - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 1.0000
# Epoch 31/50
#  - 4s - loss: 0.0661 - accuracy: 0.9808 - val_loss: 0.1599 - val_accuracy: 1.0000
# Epoch 32/50
#  - 3s - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9583
# Epoch 33/50
#  - 4s - loss: 0.0711 - accuracy: 0.9821 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 34/50
#  - 3s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 35/50
#  - 3s - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 36/50
#  - 2s - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 37/50
#  - 4s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 38/50
#  - 5s - loss: 0.0309 - accuracy: 0.9821 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 39/50
#  - 3s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 40/50
#  - 3s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 41/50
#  - 3s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 42/50
#  - 2s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 43/50
#  - 5s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 44/50
#  - 4s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 45/50
#  - 3s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 46/50
#  - 3s - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 47/50
#  - 3s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 48/50
#  - 3s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 49/50
#  - 4s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 50/50
#  - 4s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Akurasi Model: 100.00000
# Waktu running Model = 0:02:54.019994

# %%
### tebak gambar
# open image
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import os
 
# load and prepare the image
def load_image(folder):
  images = []
  filenames = []
  for filename in os.listdir(folder):
    img = load_img(os.path.join(folder,filename), target_size=(200, 200))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 3 channels
    img = img.reshape(1, 200, 200, 3)
    img = img.astype('uint8')
    images.append(img)
    filenames.append(filename.replace(".jpg", " "))
  return images, filenames

# %%
coba,nama = load_image('/content/gdrive/My Drive/Colab Notebooks/Dataset/RIPCurrent_keras/coba/')

# %%
(coba[2].shape)
#len(coba)
#type(coba[1])
#print(coba[1])
#print(nama[1])
# Out:
# (1, 200, 200, 3)

# %%
# load an image and predict the class
def run_example(img,name):
  import matplotlib.pyplot as plt
  import pandas as pd
  import numpy as np

  # load model
  model = load_model('rip_model.h5')
  #print(model.summary())
  # predict the class
  result = model.predict(img)
  plt.figure()
  img = img.reshape(200, 200, 3)
  #img = imread(img)
  imgplot = plt.imshow(img)
  plt.title('Nama File asli : {}'.format(name))
  a = np.asarray(result)
  hasil_klasifikasi = pd.DataFrame(a)
  hasil_klasifikasi.columns = ['norip', 'rip 1', 'rip 2'] 
  print ('   Hasil prediksi model : ')
  print(hasil_klasifikasi)

# %%
run_example(coba[14],nama[14])
# Out:
#    Hasil prediksi model :
#    norip  rip 1  rip 2
# 0    0.0    0.0    1.0

# %%
model = load_model('rip_model.h5')
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 200, 200, 8)       224
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 100, 100, 8)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 80000)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                1280016
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 1,280,291
# Trainable params: 1,280,291
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9ae23eef65cb> in <module>()
# ----> 1 hist_df = pd.DataFrame(history.history)
#
# NameError: name 'history' is not defined
